# %% [markdown]
# CONNECTION

# %%
from pathlib import Path

from dotenv import load_dotenv
from openai import OpenAI

load_dotenv(Path.cwd() / ".env")
client = OpenAI()
response = client.responses.create(
    model="gpt-4o-mini",
    input="Tell me a fun fact about data engineering",
)
print(response.output)
# Out:
# [ResponseOutputMessage(id='msg_0918a8ec538231650069daa9736a9881a0a500010b8e771a3e', content=[ResponseOutputText(annotations=[], text='A fun fact about data engineering is that the term "big data" was popularized in the early 2000s, but the concept has been around much longer! For example, the term "data mining" emerged in the 1990s, and organizations were already trying to analyze large datasets long before the tools we use today, like Hadoop and Spark, were developed. This shows how the field has evolved rapidly, yet the quest to make sense of data has been a critical part of business and science for decades!', type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase=None)]

# %% [markdown]
# EMBEDDINGS

# %%
response = client.embeddings.create(
    input="Your",
    model="text-embedding-3-small"
)

print(response.data[0].embedding)
# Out:
# [0.04888916015625, -0.0234527587890625, -0.00437164306640625, 0.049468994140625, 0.001918792724609375, -0.029754638671875, -0.002593994140625, 0.040130615234375, -0.0022754669189453125, -0.036285400390625, -0.01202392578125, 0.0421142578125, -0.0234222412109375, -0.023590087890625, 0.01482391357421875, 0.032440185546875, -0.031982421875, -0.03704833984375, 0.017181396484375, 0.01160430908203125, 0.024749755859375, 0.039337158203125, 0.044586181640625, 0.0007982254028320312, -0.0185699462890625, 0.020782470703125, -0.00469970703125, 0.01519775390625, 0.00862884521484375, -0.0017671585083007812, 0.025421142578125, -0.036865234375, 0.0296630859375, -0.01399993896484375, -0.0211334228515625, 0.00675201416015625, 3.337860107421875e-05, 0.01322174072265625, -0.0174102783203125, -0.0380859375, 0.0274200439453125, -0.03369140625, 0.014801025390625, -0.0018672943115234375, 0.042724609375, 0.052490234375, -0.059661865234375, -0.0034027099609375, 0.073974609375, -0.00399017333984375, -0.001438140869140625, 0.01113128662109375, -0.012420654296875, 0.087646484375, -0.0175933837890625, -0.0144195556640625, 0.01082611083984375, 0.04132080078125, -0.00909423828125, -0.0088043212890625, -0.0170440673828125, 0.0106658935546875, 0.0054168701171875, 0.0109405517578125, 0.0133514404296875, -0.0335693359375, -0.031768798828125, 0.036041259765625, -0.01091766357421875, -0.00257110595703125, 0.01959228515625, 0.016357421875, -0.021636962890625, -0.00397491455078125, -0.0029735565185546875, -0.01441192626953125, -0.01904296875, -0.01263427734375, 